# %%
import requests
import bs4
res=requests.get('https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off')
# from bs4 import *
# type(res)
import pandas as pd
soup=bs4.BeautifulSoup(res.text,'lxml')
name=soup.select('._3wU53n')
price=soup.select('._1vC4OE')
names=[]
prices=[]

# for i in name:
#     print(i.text)
##for i,j in zip(name,price):
    ##print(i.text,j.text)
# for j in price:
#     print(j.text)
for i in range(24):
    names.append(name[i].text)
    prices.append(price[i].text)
list=pd.DataFrame({'product':names,'links':prices})
list.to_excel('data.xls')
list
# Out:
#                                               product    links
# 0   HP 15q Core i3 7th Gen - (4 GB/1 TB HDD/DOS) 1...  ₹28,990
# 1   Acer Aspire 3 Pentium Quad Core - (4 GB/500 GB...  ₹20,990
# 2   Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  ₹67,990
# 3   Dell Inspiron 14 3000 Series Core i3 7th Gen -...  ₹26,490
# 4   HP 15 Core i3 7th Gen - (4 GB/1 TB HDD/Windows...  ₹32,490
# 5   Acer Aspire 3 Celeron Dual Core - (2 GB/500 GB...  ₹16,990
# 6   Lenovo Ideapad 330 Core i5 8th Gen - (8 GB/1 T...  ₹43,990
# 7   Asus APU Quad Core E2 - (4 GB/500 GB HDD/Windo...  ₹18,990
# 8   HP 15 APU Dual Core A9 - (4 GB/1 TB HDD/Window...  ₹24,990
# 9   HP 15q Core i5 7th Gen - (8 GB/1 TB HDD/Window...  ₹41,990
# 10  HP 14q Core i3 7th Gen - (4 GB/1 TB HDD/DOS) 1...  ₹27,990
# 11  HP 15 Core i3 7th Gen - (4 GB/1 TB HDD/Windows...  ₹31,590
# 12  Dell Vostro 15 3000 Core i3 6th Gen - (4 GB/1 ...  ₹26,990
# 13  Lenovo Ideapad 320 Core i3 6th Gen - (4 GB/1 T...  ₹25,990
# ...

# %%
# Out:
# Acer Aspire 3 Pentium Quad Core - (4 GB/500 GB HDD/Windows 10 Home) A315-33 Laptop ₹20,990
# HP 15q Core i3 7th Gen - (4 GB/1 TB HDD/DOS) 15q-bu037TU Laptop ₹28,990
# Dell Inspiron 14 3000 Series Core i3 7th Gen - (4 GB/1 TB HDD/Linux) 3467 Laptop ₹26,490
# HP 15 Core i3 7th Gen - (4 GB/1 TB HDD/Windows 10 Home) 15-da0327TU Laptop ₹32,490
# Acer Aspire 3 Celeron Dual Core - (2 GB/500 GB HDD/Linux) A315-33 Laptop ₹16,990
# HP 15 APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 15-bw519AU Laptop ₹24,990
# Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466 ₹67,990
# HP 15q Core i5 7th Gen - (8 GB/1 TB HDD/Windows 10 Home) 15q-bu044TU Laptop ₹41,990
# Lenovo Ideapad 320 Core i3 6th Gen - (4 GB/1 TB HDD/DOS) IP 320-15ISK Laptop ₹25,990
# Asus APU Quad Core E2 - (4 GB/500 GB HDD/Windows 10 Home) X540YA-XO760T Laptop ₹18,990
# Lenovo Ideapad 330 Core i5 8th Gen - (8 GB/1 TB HDD/DOS/2 GB Graphics) 330-15IKB Laptop ₹43,990
# ...

# %%
import requests
import bs4
res=requests.get('https://www.amazon.in/gp/bestsellers/electronics/1375424031/ref=sr_bs_0_1375424031_1')
# from bs4 import *
# type(res)
soup=bs4.BeautifulSoup(res.text,'lxml')
name=soup.find_all('div',{'class':'p13n-sc-truncated'})
for i in name:
    print(i.text)
    print(i['HP 15 AMD E2 15.6-inch Entry Level Laptop (4GB /1TB HDD/Windows 10 Home/Jet Black/2.04 Kgs), 15q-bw548AU'])
price=soup.select('.p13n-sc-price')
#print(name)
for i in price:
    print(i.text)
#price=soup.select('._1vC4OE')
# for i in name:
#     print(i.text)
#for i,j in zip(name,price):
  #  print(i.text,j.text)
# for j in price:
#     print(j.text
print(name)
# Out:
#    20,990.00
#    67,990.00
#    41,990.00
#    40,990.00
#    26,990.00
#    9,499.00
#    30,990.00
#    31,164.00
#    27,990.00
#    46,990.00
#    42,849.00
#    33,099.00
#    22,191.00
#    18,990.00
#    14,181.00
#    26,990.00
#    29,990.00
#    24,490.00
#    17,898.00
#    43,990.00
#    24,990.00
#    26,300.00
#    48,490.00
#    58,990.00
#    56,990.00
#    32,499.00
#    32,990.00
#    17,795.00
#    29,990.00
#    25,490.00
#    31,990.00
#    47,490.00
#    27,490.00
#    28,990.00
#    27,990.00
#    20,490.00
#    17,990.00
#    47,300.00
#    75,990.00
#    43,197.00
#    18,990.00
#    21,490.00
#    62,980.00
#    59,990.00
#    71,987.00
#    55,990.00
#    27,997.00
#    31,990.00
#    61,990.00
#    72,990.00
# []

# %%
from __future__ import unicode_literals
import youtube_dl
import urllib
import shutil
ydl_opts = {}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    
    ydl.download(['https://www.youtube.com/watch?v=n06H7OcPd-g'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-8591c271fe04> in <module>
#       1
#       2 from __future__ import unicode_literals
# ----> 3 import youtube_dl
#       4 import urllib
#       5 import shutil
#
# ModuleNotFoundError: No module named 'youtube_dl'

# %%
import requests

# %%
response=requests.get('https://www.amazon.in/')
print(response.text)
# Out:
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"><!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'><link rel='dns-prefetch' href='//images-eu.ssl-images-amazon.com'><link rel='dns-prefetch' href='//m.media-amazon.com'><link rel='dns-prefetch' href='//completion.amazon.com'><!-- sp:feature:aui-assets -->
# ...

# %%
import bs4

# %%
soup=bs4.BeautifulSoup(response.text,'lxml')

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'HTML_FORMATTERS',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_attr_value_as_string',
#  '_attribute_checker',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
# ...

# %%
soup.title
# Out:
# <title>Online Shopping site in India: Shop Online for Mobiles, Books, Watches, Shoes and More - Amazon.in</title>

# %%
imgs=soup.find_all('img')

# %%
type(imgs)
# Out:
# bs4.element.ResultSet

# %%
len(imgs)
# Out:
# 68

# %%
imgs[0]
# Out:
# <img alt="" src="https://images-eu.ssl-images-amazon.com/images/G/31/gno/sprites/nav-sprite-global_bluebeacon-V3-1x_optimized._CB516557522_.png" style="display:none"/>

# %%
imgs[0]['src']
# Out:
# 'https://images-eu.ssl-images-amazon.com/images/G/31/gno/sprites/nav-sprite-global_bluebeacon-V3-1x_optimized._CB516557522_.png'

# %%
type(imgs[0])
# Out:
# bs4.element.Tag

# %%
dir(imgs[0])
# Out:
# ['HTML_FORMATTERS',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_attr_value_as_string',
#  '_attribute_checker',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_select_debug',
#  '_selector_combinators',
#  '_should_pretty_print',
#  '_tag_name_matches_and',
#  'append',
#  'attribselect_re',
#  'attrs',
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
response=requests.get(imgs[0]['src'],stream=True)
img=Image.open(response.raw)
plt.imshow(img)
img.save('/Macintosh HD⁩/⁨Users⁩/⁨ranjanchoudhary⁩/⁨Desktop/scrap/'+str(k)+'.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-270d48d2f784> in <module>
#       4 img=Image.open(response.raw)
#       5 plt.imshow(img)
# ----> 6 img.save('/Macintosh HD⁩/⁨Users⁩/⁨ranjanchoudhary⁩/⁨Desktop/scrap/'+str(k)+'.jpg')
#
# NameError: name 'k' is not defined

# %%
import matplotlib.pyplot as plt
from PIL import Image
response=requests.get(imgs[0]['src'],stream=True)
Image.open(response.raw).convert('RGB').save('NAavg.jpg')
# Out:
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +

# %%
import matplotlib.pyplot as plt
from PIL import Image
for k in range(10):

    response=requests.get(imgs[k]['src'],stream=True)
    Image.open(response.raw).convert('RGB').save('NAavg.jpg')

# %%
import requests
from bs4 import*
#from PIL import image
import matplotlib.pyplot as plt
link=input('enter your link')
req=requests.get(link)
soup=BeautifulSoup(req.text,'lxml')
imgs=soup.find_all('imgs')
k=1
for i in imgs:
    try:
        url=i['src']
        print('Image Link:',k)
        print(url)
        response=requests.get(url,stream=True)
        img=Image.open(response.raw)
        #plt.imshow(img)
        img.save(r'/Downloads',+str[i],'.jpg')
    except:
        KeyError
    else:
        pass
# Out:
# enter your linkhttps://www.amazon.in/?ie=UTF8&tag=googinabkkenshoo-21&ascsubtag=_k_EAIaIQobChMIppbkocPR3wIVyBwrCh3WYgakEAAYASAAEgJCW_D_BwE_k_&gclid=EAIaIQobChMIppbkocPR3wIVyBwrCh3WYgakEAAYASAAEgJCW_D_BwE

# %%
|
# Out:
#   File "<ipython-input-88-d080f40a83c1>", line 1
#     |
#     ^
# SyntaxError: invalid syntax
