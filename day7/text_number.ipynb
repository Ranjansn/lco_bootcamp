# %%
import re
with open("RTI_9.txt","r") as f:
    c=f.read()
    l=re.findall("\S+@\S+",c)
    p=re.findall('\d\d\d\d\d-\d\d\d\d\d',c)
    m=len(p)
    for i in range(len(l)):
        print(l[i],end="   ")
        if i<m-1:
            print(p[i])
        print()
# Out:
# minessecretary@dmg-   99291-08338
#
# jsmines-rj@nic.in   75977-89216
#
# minessecretary@dmg-   94148-28210
#
# osd@dmg-raj.org   94140-46157
#
# supgeosect@dmg-raj.org   98293-64471
#
# director@dmg-raj.org   89520-70405
#
# admed@dmg-raj.org   94142-75509
#
# admhq@dmg-raj.org   94140-97200
#
# adghq@dmg-raj.org   94143-43717
#
# ada@dmg-raj.org   94140-42843
#
# fa@dmg-raj.org   94140-33794
#
# smevighq@dmg-raj.org   97991-68501
#
# smeplan@dmg-raj.org   94142-64334
#
# major.cell@dmg-raj.org   94140-33794
#
# minor.cell@dmg-raj.org   94143-91920
#
# ta.dmg@dmg-raj.org   94143-91920
#
# supgeohq@dmg-raj.org   94611-79587
#
# supgeo.rs@dmg-raj.org   94147-37304
#
# supgeophy@dmg-raj.org   94145-57745
#
# srchemeng@dmg-raj.org   94142-89073
#
# sg.hq@dmg-raj.org   94141-62364
#
# ad.stat@dmg-raj.org   92527-95320
#
# smeplan@dmg-raj.org   94600-08059
#
# sg.rs@dmg-raj.org   94145-57745
#
# po@dmg-raj.org   94140-33794
#
# supgeophy@dmg-raj.org   94612-90828
#
# ...
