# %% [markdown]
# ## P1
#
# ### Implement Binary Search For An Sorted Array (Assume Array Is Sorted)

# %%
list1=list(map(int,input().split()))
num=int(input())
r=0
l=int(len(list1))

def binarysearch(list1,num,r,l):
    mid=(r+l)//2
    if l-r==0:
        return False
    elif  num==list1[mid]:
        return(True)
    elif num<list1[mid]:
        return(binarysearch(list1,num,r,mid-1))
    else:
        return(binarysearch(list1,num,mid+1,l))

binarysearch(list1,num,r,l)

# %% [markdown]
# ## P2
#
# ### Implement Gates: (Output Is Always Going To Be In The Form Of Binary Inputs 0 or 1)
#
# + OR gate
# + NOT gate
# + AND gate
# + NAND gate
# + XOR gate
# + NOR gate

# %%
a=int(input('enter binary value'))
b=int(input('enter binary value'))
if a==1 or a==0:
    if b==1 or b==0:      
        andg=a*b
        print('output in and gate :-',andg)
        org=1 if andg==0 else 0
        print('output in nand gate is :- ',org)
        notg1=1 if a==0 else 1
        notg2=1 if b==0 else 1
        print('output in not gate for a is:-',notg1)
        print('output in not gate for  is:-',notg2)
        if(a==0):
            if(b==0):
                print('output in or gate is :-0')
            else:
                print('output in or gate is :-1')
        else:
            print('output in or gate is:1')
        if(a==0):
            if(b==0):
                print('output in nor gate is :-1')
            else:
                print('output in nor gate is :-0')
        else:
            print('output in nor gate is:0')
        if(a==b):
            print('output in xor gate is :- 0')
        else:
            print('output in xor gate is : -1')
    else:
        print('only enter 1 or 0')
else:
    print('only enter 1 or 0')
# Out:
# enter binary value3
# enter binary value5
# only enter 1 or 0

# %%
def nott(a):
    print('0') if a==1 else print('1')
def AND (a,b):

    if a == 1 and b == 1:
        return 1
    else:
        return 0



def NAND (a,b):
    if a == 1 and b == 1:
        return 0
    else:
        return 1


def OR(a,b):
    if a == 1:
        return 1
    elif b == 1:
        return 1
    else:
        return 0


def NOR (a,b):
    if a != b:
        return 1
    else:
        return 1
def XOR(a,b):
    if a==1 and b==1:
        return(False)
    elif (a==1 or b==0) or (a==0 or b==1) :
        return True
    if a==0 and b==0:
        return(False)
n=list(map(int,input().split()))
a=n[0]
b=n[1]
XOR(a,b)

# %% [markdown]
# # P3
#
# ### Build An Calculator

# %%
print("what you want to do\n",'1=add\n','2=subtract\n','3=multiply\n','4=divide\n')
choice = input("Enter choice(1/2/3/4):")

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if choice == '1':
   print(num1,"+",num2,"=", add(num1,num2))

elif choice == '2':
   print(num1,"-",num2,"=", subtract(num1,num2))

elif choice == '3':
   print(num1,"*",num2,"=", multiply(num1,num2))

elif choice == '4':
   print(num1,"/",num2,"=", divide(num1,num2))
else:
   print("try with another input")
def main():
    def add(x, y):
       return x + y
    def subtract(x, y):
       return x - y
    def multiply(x, y):
       return x * y
    def divide(x, y):
       return x / y

if __name__ =="__main__": main()
# Out:
# what you want to do
#  1=add
#  2=subtract
#  3=multiply
#  4=divide
#
# Enter choice(1/2/3/4):4
# Enter first number: 3
# Enter second number: 2
# 3 / 2 = 1.5

# %% [markdown]
# ## P4
#
# Question:
# Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional array. The element value in the i-th row and j-th column of the array should be i*j.
# Note: i=0,1.., X-1; j=0,1,¡­Y-1.
#
# Example
#
# Suppose the following inputs are given to the program:
#
# 3,5
#
# Then, the output of the program should be:
#
# [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]
#
# Hints:
# Note: In case of input data being supplied to the question, it should be assumed to be a console input in a comma-separated for

# %%
print("Enter the number of elements:")
m=int(input())
print("Enter the number of list:")
n=int(input())
l=[[0 for i in range(m)] for j in range(n)]
for i in range(n):
    for j in range(m):
        for k in range(i+1):
            if k==i:
                if j>0:
                    l[i][j]=l[i][j-1]+i
                
        #if i==1:
          #  if j>0:
           #     l[i][j]=l[i][j-1]+1
        #if i==2:
        #    if j>0:
         #       l[i][j]=l[i][j-1]+2
print(l)

# %% [markdown]
# ## P5
#
# ### Implement Mathematics Linear Equation :
#
# #                     y = mx + c

# %%
import matplotlib.pyplot as plt
y3=list(map(int,input().split()))
x3=list(map(int,input().split()))
y1=y3[0]
y2=y3[1]
x1=x3[0]
x2=x3[1]
m=(y2-y1)/(x2-x1)
p=str(m)
print("Required equation will be:") 
print("y",y1,"=",p+"x","-",m*x1,sep="")
plt.plot(y3,x3)

# %% [markdown]
# ## P6
#
# Write a program that accepts sequence of lines as input and prints the lines after making all characters in the sentence capitalized.
# Suppose the following input is supplied to the program:
#
# Hello world
# Practice makes perfect
#
# Then, the output should be:
#
# HELLO WORLD
# PRACTICE MAKES PERFECT

# %%
x=str(input())
x.upper()

# %% [markdown]
# ## P6
#
# ### Implement Functions:(Use Numpy)
#
# + Sigmoid
# + Tanh
# + ReLu
# + Leaky ReLu
# + Identity
# + Binary

# %% [markdown]
# ## P7
#
# ### Implement How To Find Mean(), Variance(), Standard Deviation().

# %%
import statistics
m=list(map(int,input().split()))
statistics.mean(m)
statistics.variance(m)
statistics.stdev(m)

# %% [markdown]
# ## P8
#
# Question:
# Write a program which accepts a sequence of comma separated 4 digit binary numbers as its input and then check whether they are divisible by 5 or not. The numbers that are divisible by 5 are to be printed in a comma separated sequence.
#
# Example:
#
# 0100,0011,1010,1001
#
# Then the output should be:
#
# 1010

# %%
binary = list(input().split(","));
x=[]
for i in range(len(binary)):
              decimal = int(binary[i], 2);
              if decimal%5==0:
                  x.append(binary[i])
for i in x:
              print(i)

# %% [markdown]
# ## P9
#
# ### Question:
#
# Write a program, which will find all such numbers between 1000 and 3000 (both included) such that each digit of the number is an even number.
# The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
for i in range(1000,3000):
    i=str(i)
    if (int(i[0])%2==0 and int(i[1])%2==0 and int(i[2])%2==0 and int(i[3])%2==0):
        print(i)
# Out:
# 2000
# 2002
# 2004
# 2006
# 2008
# 2020
# 2022
# 2024
# 2026
# 2028
# 2040
# 2042
# 2044
# 2046
# 2048
# 2060
# 2062
# 2064
# 2066
# 2068
# 2080
# 2082
# 2084
# 2086
# 2088
# 2200
# 2202
# 2204
# 2206
# 2208
# 2220
# 2222
# 2224
# 2226
# 2228
# 2240
# 2242
# 2244
# 2246
# 2248
# 2260
# 2262
# 2264
# 2266
# 2268
# 2280
# 2282
# 2284
# 2286
# 2288
# 2400
# 2402
# 2404
# 2406
# 2408
# 2420
# 2422
# 2424
# 2426
# 2428
# 2440
# 2442
# 2444
# 2446
# 2448
# 2460
# 2462
# 2464
# 2466
# 2468
# 2480
# 2482
# 2484
# 2486
# 2488
# 2600
# 2602
# 2604
# 2606
# 2608
# 2620
# 2622
# 2624
# 2626
# 2628
# 2640
# 2642
# 2644
# 2646
# 2648
# 2660
# 2662
# 2664
# 2666
# 2668
# 2680
# 2682
# 2684
# 2686
# 2688
# 2800
# 2802
# 2804
# 2806
# 2808
# 2820
# 2822
# 2824
# 2826
# 2828
# 2840
# 2842
# 2844
# 2846
# 2848
# 2860
# 2862
# 2864
# 2866
# 2868
# 2880
# 2882
# 2884
# 2886
# 2888

# %% [markdown]
# ## P10
#
# Question:
# Write a program that accepts a sentence and calculate the number of letters and digits.
# Suppose the following input is supplied to the program:
#
# hello world! 123
#
# Then, the output should be:
#
# LETTERS 10
#
# DIGITS 3

# %%
import string
x=list(input())
num=0
for i in range(len(x)):
    if x[i] in string.ascii_letters:
        num+=1
dict1=[]
for i in range(9):
    dict1.append(str(i))
    #print(dict1)
digit=0
for i in range(len(x)):
    if x[i] in dict1:
        digit+=1
print("LETTERS",num)
print("DIGITS",digit)

# %% [markdown]
# ## P11
#
# Question:
# A website requires the users to input username and password to register. Write a program to check the validity of password input by users.
#
# Following are the criteria for checking the password:
#
# 1. At least 1 letter between [a-z]
#
# 2. At least 1 number between [0-9]
#
# 1. At least 1 letter between [A-Z]
#
# 3. At least 1 character from [$#@]
#
# 4. Minimum length of transaction password: 6
#
# 5. Maximum length of transaction password: 12
#
# Your program should accept a sequence of comma separated passwords and will check them according to the above criteria. Passwords that match the criteria are to be printed, each separated by a comma.
# Example
#
# If the following passwords are given as input to the program:
#
# ABd1234@1,a F1#,2w3E*,2We3345
#
# Then, the output of the program should be:
#
# ABd1234@1

# %%
# Answer
# Hint use Regular Expression
import re
user=input("Enter your password:")
x="(?=.*[A-Za-z])(?=.*\d)(?=.*[@#$])[a-zA-Z0-9@#$]{6,12}"
p=re.findall(x,user)
if len(p)==0:
    print("False")
elif p[0] in user:
    print("True")
else:
    print("False")
