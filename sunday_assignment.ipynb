# %% [markdown]
#  #### you have to print "learncodeonline" using start pattern
#
#
#
#     *
#     *
#     *
#     *
#     *
#     *
#     *******
#
#
#     *******
#     *
#     *
#     *******
#     *
#     *
#     *******
#
#
#     *******
#     *     *
#     *     *
#     *******
#     *     *
#     *     *
#     *     *
#
#     *******
#     *     *
#     *     *
#     *******
#     *  *
#     *   *
#     *    *
#
#     *     *
#     **    *
#     * *   *
#     *  *  *
#     *   * *
#     *    **
#     *     *
#
#     *******
#     *
#     *
#     *
#     *
#     *
#     *******
#
#     *******
#     *     *
#     *     *
#     *     *
#     *     *
#     *     *
#     *******
#
#     *******
#       *   *
#       *   *
#       *   *
#       *   *
#       *   *
#     *******
#
#     *******
#     *
#     *
#     *******
#     *
#     *
#     *******
#
#     *******
#     *     *
#     *     *
#     *     *
#     *     *
#     *     *
#     *******
#
#     *     *
#     **    *
#     * *   *
#     *  *  *
#     *   * *
#     *    **
#     *     *
#
#     *
#     *
#     *
#     *
#     *
#     *
#     *******
#
#     *******
#        *
#        *
#        *
#        *
#        *
#     *******
#
#     *     *
#     **    *
#     * *   *
#     *  *  *
#     *   * *
#     *    **
#     *     *
#
#     *******
#     *
#     *
#     *******
#     *
#     *
#     *******

# %% [markdown]
# ### question2
#
# you are having a list and this list is having some repetetive number or characters. now task is you have to find the non repeatetive numbers or characes in the list

# %%
#answer

# %% [markdown]
# #### note: it is reallife prototype
# ### Shopping Mall
# ### Question 3
#
# you have to make a shopping mall application in which you would have some category {"food", "wears","toys"....}
# every category would have respective elements like( food category would have pizza,burger kind of things with prize)
#
# the another feature you have a cart in which you will have all purchased item.
#
#
# finally when user will ask for bill then you have calculate the prize of product and print an awesome bill with product name and prize.

# %% [markdown]
# ### Question 4
# ### Atm prototype
#
# this prototype would have some feature which is given below
#
# * login
# * withdraw
# * pinchange
# * mini_statement

# %% [markdown]
# ### Question 5
# ### currency converter
